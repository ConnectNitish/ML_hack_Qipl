# %% [markdown]
# <a href="https://colab.research.google.com/github/ConnectNitish/ML_hack_Qipl/blob/main/Data_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/ConnectNitish/ML_hack_Qipl/main/beginner/train_data/training_data.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Row_ID  ...  shares
# 0       1  ...     593
# 1       2  ...     711
# 2       3  ...    1500
# 3       5  ...     505
# 4       6  ...     855
#
# [5 rows x 61 columns]

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(data)
prof.to_file(output_file='./output_beg.html')

# %%
# ls
# pwd
